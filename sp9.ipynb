# %% [markdown]
# <a href="https://colab.research.google.com/github/miikousin/Colab-Notebooks/blob/main/sp9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 変数urlにSUUMOホームページのURLを格納する
url = 'https://suumo.jp/chintai/tokyo/sc_shinjuku/?page={}'

# 変数d_listに空のリストを作成する
d_list = []

# アクセスするためのURLをtarget_urlに格納する
for i in range(1, 3):
    print('d_listの大きさ：', len(d_list))
    target_url = url.format(i)

    # print()してtarget_urlを確認する
    print(target_url)

    # target_urlへのアクセス結果を、変数rに格納
    r = requests.get(target_url)

    sleep(1)

    # 取得結果を解析してsoupに格納
    soup = BeautifulSoup(r.text)

    # すべての物件情報(20件)を取得する
    contents = soup.find_all('div', class_='cassetteitem')

    # 各物件情報をforループで取得する
    for content in contents:
        # 物件情報と部屋情報を取得しておく
        detail = content.find('div', class_='cassetteitem_content')
        table = content.find('table', class_='cassetteitem_other')

        # 物件情報から必要な情報を取得する
        title = detail.find('div', class_='cassetteitem_content-title').text
        address = detail.find('li', class_='cassetteitem_detail-col1').text
        access = detail.find('li', class_='cassetteitem_detail-col2').text
        age = detail.find('li', class_='cassetteitem_detail-col3').text

        # 部屋情報のブロックから、各部屋情報を取得する
        tr_tags = table.find_all('tr', class_='js-cassette_link')

        # 各部屋情報をforループで取得する
        for tr_tag in tr_tags:

            # 部屋情報の行から、欲しい情報を取得する
            floor, price, first_fee, capacity = tr_tag.find_all('td')[2:6]

            # さらに細かい情報を取得する
            fee, management_fee = price.find_all('li')
            deposit, gratuity = first_fee.find_all('li')
            madori, menseki = capacity.find_all('li')

            # 取得したすべての情報を辞書に格納する
            d = {
                'title': title,
                'address': address,
                'access': access,
                'age': age,
                'floor': floor.text,
                'fee': fee.text,
                'management_fee': management_fee.text,
                'deposit': deposit.text,
                'gratuity': gratuity.text,
                'madori': madori.text,
                'menseki': menseki.text
            }

            # 取得した辞書をd_listに格納する
            d_list.append(d)
# Out:
# d_listの大きさ： 0
# https://suumo.jp/chintai/tokyo/sc_shinjuku/?page=1
# d_listの大きさ： 140
# https://suumo.jp/chintai/tokyo/sc_shinjuku/?page=2

# %%
d_list[:2]
# Out:
# [{'title': 'ザ・パークハウス市谷加賀町',
#   'address': '東京都新宿区市谷加賀町２',
#   'access': '\n都営大江戸線/牛込柳町駅 歩4分\n都営新宿線/曙橋駅 歩12分\n東京メトロ有楽町線/市ケ谷駅 歩16分\n',
#   'age': '\n築11年\n地下1地上5階建\n',
#   'floor': '\r\n\t\t\t\t\t\t\t\t\t\t\t5階',
#   'fee': '33.5万円',
#   'management_fee': '-',
#   'deposit': '33.5万円',
#   'gratuity': '33.5万円',
#   'madori': '3LDK',
#   'menseki': '73.97m2'},
#  {'title': 'ザ・パークハウス早稲田',
#   'address': '東京都新宿区戸山３',
#   'access': '\n東京メトロ東西線/早稲田駅 歩6分\n東京メトロ副都心線/西早稲田駅 歩13分\n都電荒川線/早稲田駅 歩14分\n',
#   'age': '\n築5年\n地下1地上10階建\n',
#   'floor': '\r\n\t\t\t\t\t\t\t\t\t\t\t5階',
#   'fee': '28万円',
#   'management_fee': '-',
#   'deposit': '28万円',
#   'gratuity': '28万円',
#   'madori': '2LDK',
#   'menseki': '55.31m2'}]

# %%
df = pd.DataFrame(d_list)

# %%
df.head()
# Out:
#            title       address  \
# 0  ザ・パークハウス市谷加賀町  東京都新宿区市谷加賀町２
# 1    ザ・パークハウス早稲田     東京都新宿区戸山３
# 2    ザ・パークハウス早稲田     東京都新宿区戸山３
# 3        ブラン高田馬場   東京都新宿区高田馬場３
# 4        ドゥーエ早稲田   東京都新宿区西早稲田２
#
#                                               access                 age  \
# 0  \n都営大江戸線/牛込柳町駅 歩4分\n都営新宿線/曙橋駅 歩12分\n東京メトロ有楽町線/...  \n築11年\n地下1地上5階建\n
# 1  \n東京メトロ東西線/早稲田駅 歩6分\n東京メトロ副都心線/西早稲田駅 歩13分\n都電荒...  \n築5年\n地下1地上10階建\n
# 2  \n東京メトロ東西線/早稲田駅 歩6分\n東京メトロ副都心線/西早稲田駅 歩13分\n都電荒...  \n築5年\n地下1地上10階建\n
# 3  \n西武新宿線/下落合駅 歩5分\nＪＲ山手線/高田馬場駅 歩14分\n東京メトロ東西線/落...        \n築6年\n3階建\n
# 4  \n東京メトロ東西線/早稲田駅 歩6分\n東京メトロ副都心線/西早稲田駅 歩9分\n都電荒川...  \n築4年\n地下1地上10階建\n
#
#                            floor     fee management_fee deposit gratuity  \
# 0   \r\n\t\t\t\t\t\t\t\t\t\t\t5階  33.5万円              -  33.5万円   33.5万円
# 1   \r\n\t\t\t\t\t\t\t\t\t\t\t5階    28万円              -    28万円     28万円
# 2   \r\n\t\t\t\t\t\t\t\t\t\t\t5階    46万円              -    46万円     46万円
# 3   \r\n\t\t\t\t\t\t\t\t\t\t\t1階  10.7万円          3000円  10.7万円   10.7万円
# 4  \r\n\t\t\t\t\t\t\t\t\t\t\tB1階  15.5万円         10000円  15.5万円        -
#
#   madori  menseki
# 0   3LDK  73.97m2
# 1   2LDK  55.31m2
# 2   3LDK  83.51m2
# 3   1LDK  28.23m2
# 4   1LDK  35.55m2

# %%
df.shape
# Out:
# (289, 11)

# %%
len(df.title.unique())
# Out:
# 39

# %%
df.to_csv('test.csv', index=None, encoding='utf-8-sig')
